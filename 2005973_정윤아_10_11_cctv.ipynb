# %%
import pandas as pd

CCTV_Seoul = pd.read_csv('서울시CCTV설치운영현황(자치구)_년도별_210731기준.csv', skiprows = [0, 2], encoding='CP949', thousands=',')
CCTV_Seoul.head()
# Out:
#     구분    총계  2012년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년  \
# 0  종로구  1772       813      0      0    210    150      1    261     85
# 1  중 구  2333        16    114     87     77    236    240    372    386
# 2  용산구  2383        34     71    234    125    221    298    351    125
# 3  성동구  3602       448    125    212    105    339    310    874    390
# 4  광진구  2588        35     57    100    187     98     52    675    465
#
#    2019년  2020년  2021년
# 0      9    200     43
# 1    155    361    289
# 2    307    617      0
# 3    262    461     76
# 4    712    175     32

# %%
# 열 정보 확인
CCTV_Seoul.columns
# Out:
# Index(['구분', '총계', '2012년 이전', '2012년', '2013년', '2014년', '2015년', '2016년',
#        '2017년', '2018년', '2019년', '2020년', '2021년'],
#       dtype='object')

# %%
# 0번째 열 확인
CCTV_Seoul.columns[0]
# Out:
# '구분'

# %%
# 열 이름 변경
# inplace 옵션으로 원본 직접 수정
CCTV_Seoul.rename(columns = {CCTV_Seoul.columns[0]: '자치구'}, inplace = True)
CCTV_Seoul.head()
# Out:
#    자치구    총계  2012년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년  \
# 0  종로구  1772       813      0      0    210    150      1    261     85
# 1  중 구  2333        16    114     87     77    236    240    372    386
# 2  용산구  2383        34     71    234    125    221    298    351    125
# 3  성동구  3602       448    125    212    105    339    310    874    390
# 4  광진구  2588        35     57    100    187     98     52    675    465
#
#    2019년  2020년  2021년
# 0      9    200     43
# 1    155    361    289
# 2    307    617      0
# 3    262    461     76
# 4    712    175     32

# %%
pop_Seoul = pd.read_excel('서울시주민등록인구통계_2020.xls')
pop_Seoul.head()
# Out:
#          기간  자치구       세대        인구     인구.1     인구.2     인구.3     인구.4  \
# 0        기간  자치구       세대        합계       합계       합계      한국인      한국인
# 1        기간  자치구       세대         계       남자       여자        계       남자
# 2  2020.1/4   합계  4354006  10013781  4874995  5138786  9733655  4742217
# 3  2020.1/4  종로구    74151    161984    78271    83713   151217    73704
# 4  2020.1/4   중구    63045    136469    66769    69700   126175    61839
#
#       인구.5    인구.6    인구.7    인구.8  세대당인구  65세이상고령자
# 0      한국인   등록외국인   등록외국인   등록외국인  세대당인구  65세이상고령자
# 1       여자       계      남자      여자  세대당인구  65세이상고령자
# 2  4991438  280126  132778  147348   2.24   1518239
# 3    77513   10767    4567    6200   2.04     28073
# 4    64336   10294    4930    5364      2     23794

# %%
# 앞의 2행은 중복된 헤더이므로 필요없고
# 자치구-B, 전체인구-D, 한국인 수-G, 외국인 수-J, 고령자 수-N 열만 필요함
pop_Seoul = pd.read_excel('서울시주민등록인구통계_2020.xls', header = 2,
                         usecols = 'B, D, G, J, N')
pop_Seoul.head()
# Out:
#    자치구         계      계.1     계.2  65세이상고령자
# 0   합계  10013781  9733655  280126   1518239
# 1  종로구    161984   151217   10767     28073
# 2   중구    136469   126175   10294     23794
# 3  용산구    246165   229579   16586     39439
# 4  성동구    307193   299042    8151     44728

# %%
pop_Seoul.rename(columns = {pop_Seoul.columns[0]: '자치구',
                           pop_Seoul.columns[1]: '인구수',
                           pop_Seoul.columns[2]: '한국인',
                           pop_Seoul.columns[3]: '외국인',
                           pop_Seoul.columns[4]: '고령자'},
                inplace = True)
pop_Seoul.head()
# Out:
#    자치구       인구수      한국인     외국인      고령자
# 0   합계  10013781  9733655  280126  1518239
# 1  종로구    161984   151217   10767    28073
# 2   중구    136469   126175   10294    23794
# 3  용산구    246165   229579   16586    39439
# 4  성동구    307193   299042    8151    44728

# %%
CCTV_Seoul.shape
# Out:
# (25, 13)

# %%
CCTV_Seoul.dtypes
# Out:
# 자치구         object
# 총계           int64
# 2012년 이전     int64
# 2012년        int64
# 2013년        int64
# 2014년        int64
# 2015년        int64
# 2016년        int64
# 2017년        int64
# 2018년        int64
# 2019년        int64
# 2020년        int64
# 2021년        int64
# dtype: object

# %%
CCTV_Seoul.describe()
# Out:
#               총계     2012년 이전       2012년       2013년       2014년       2015년  \
# count    25.0000    25.000000   25.000000   25.000000   25.000000   25.000000
# mean   3081.2800   306.680000   88.000000  139.640000  177.560000  263.280000
# std    1063.2148   393.645115   71.336643   89.694797  153.166326  181.918599
# min    1629.0000     0.000000    0.000000    0.000000   29.000000   79.000000
# 25%    2415.0000    35.000000   24.000000   77.000000   77.000000  141.000000
# 50%    2588.0000    83.000000   77.000000  106.000000  123.000000  209.000000
# 75%    3704.0000   448.000000  129.000000  193.000000  210.000000  329.000000
# max    6502.0000  1413.000000  253.000000  349.000000  597.000000  840.000000
#
#              2016년        2017년       2018년       2019년        2020년  \
# count    25.000000    25.000000   25.000000    25.00000    25.000000
# mean    325.160000   397.880000  395.040000   478.44000   445.280000
# std     260.103934   275.090337  208.503493   315.55072   258.230601
# min       1.000000     6.000000   85.000000     9.00000   168.000000
# 25%     168.000000   196.000000  222.000000   274.00000   288.000000
# 50%     248.000000   351.000000  386.000000   358.00000   386.000000
# 75%     350.000000   506.000000  540.000000   712.00000   508.000000
# max    1310.000000  1060.000000  867.000000  1068.00000  1213.000000
#
#             2021년
# count   25.000000
# mean    64.320000
# std     89.966531
# min      0.000000
# 25%      3.000000
# 50%     32.000000
# 75%    101.000000
# max    331.000000

# %%
CCTV_Seoul.sample(3)
# Out:
#     자치구    총계  2012년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년  \
# 15  강서구  2560        55    129    106    213    188    168    506    259
# 21  서초구  3704       116     75     94     71    563    516   1060    428
# 3   성동구  3602       448    125    212    105    339    310    874    390
#
#     2019년  2020년  2021년
# 15    457    356    123
# 21    358    420      3
# 3     262    461     76

# %%
CCTV_Seoul.sort_values(by = '총계', ascending = True).head(5)
# Out:
#     자치구    총계  2012년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년  \
# 9   도봉구  1629        39     22     96    181     79    159    134    222
# 0   종로구  1772       813      0      0    210    150      1    261     85
# 19  동작구  2297        41     24     25    503    128    253    271    300
# 1   중 구  2333        16    114     87     77    236    240    372    386
# 17  금천구  2374         0      0    178     80    361    133    196    540
#
#     2019년  2020년  2021년
# 9     198    168    331
# 0       9    200     43
# 19    322    419     11
# 1     155    361    289
# 17    369    508      9

# %%
CCTV_Seoul.sort_values(by = '총계', ascending = False).head(5)
# Out:
#     자치구    총계  2012년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년  \
# 22  강남구  6502       124     77     75    597    840   1310    999    748
# 20  관악구  4942       428    205    291    513    529    621    687    663
# 16  구로구  4075       852    216    349    187    268    326    540    488
# 7   성북구  3958        83     78    170    230    323    594    460    867
# 11  은평구  3791        14      3     44    332    329    555    403    635
#
#     2019년  2020년  2021년
# 22    789    942      1
# 20    640    331     34
# 16    434    415      0
# 7     714    251    188
# 11   1057    288    131

# %%
분자 = ((CCTV_Seoul['2021년']) + CCTV_Seoul['2020년'] + CCTV_Seoul['2019년'])
분모 = (CCTV_Seoul['2012년 이전'] + CCTV_Seoul['2013년'] + CCTV_Seoul['2014년']
      + CCTV_Seoul['2015년'] + CCTV_Seoul['2016년'] + CCTV_Seoul['2017년']
      + CCTV_Seoul['2018년'])
CCTV_Seoul['최근증가율'] = 분자 / 분모 * 100
CCTV_Seoul.head()
# Out:
#    자치구    총계  2012년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년  \
# 0  종로구  1772       813      0      0    210    150      1    261     85
# 1  중 구  2333        16    114     87     77    236    240    372    386
# 2  용산구  2383        34     71    234    125    221    298    351    125
# 3  성동구  3602       448    125    212    105    339    310    874    390
# 4  광진구  2588        35     57    100    187     98     52    675    465
#
#    2019년  2020년  2021년      최근증가율
# 0      9    200     43  16.578947
# 1    155    361    289  56.930693
# 2    307    617      0  66.570605
# 3    262    461     76  29.835698
# 4    712    175     32  57.009926

# %%
CCTV_Seoul.sort_values(by = '최근증가율', ascending = False).head(10)
# Out:
#     자치구    총계  2012년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년  \
# 8   강북구  2462         0      0     24     65    105    243      6    392
# 6   중랑구  3296       302     24    253     88    141    161    162    173
# 23  송파구  2854        72     61     86     85    215    148    241    542
# 9   도봉구  1629        39     22     96    181     79    159    134    222
# 2   용산구  2383        34     71    234    125    221    298    351    125
# 11  은평구  3791        14      3     44    332    329    555    403    635
# 15  강서구  2560        55    129    106    213    188    168    506    259
# 24  강동구  2547       332     27    163     49    154    202    273    377
# 17  금천구  2374         0      0    178     80    361    133    196    540
# 4   광진구  2588        35     57    100    187     98     52    675    465
#
#     2019년  2020년  2021년       최근증가율
# 8    1000    588     39  194.850299
# 6    1049    939      4  155.625000
# 23   1068    235    101  101.079914
# 9     198    168    331   76.593407
# 2     307    617      0   66.570605
# 11   1057    288    131   63.840830
# 15    457    356    123   62.608696
# 24    356    614      0   62.580645
# 17    369    508      9   59.543011
# 4     712    175     32   57.009926

# %%
CCTV_Seoul.sort_values(by='최근증가율', ascending = True).head(10)
# Out:
#      자치구    총계  2012년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년  \
# 0    종로구  1772       813      0      0    210    150      1    261     85
# 14   양천구  3312      1413    167    181    143    180    350    139    140
# 5   동대문구  2497      1090    146     60     29    111    233    136    197
# 20   관악구  4942       428    205    291    513    529    621    687    663
# 21   서초구  3704       116     75     94     71    563    516   1060    428
# 16   구로구  4075       852    216    349    187    268    326    540    488
# 3    성동구  3602       448    125    212    105    339    310    874    390
# 22   강남구  6502       124     77     75    597    840   1310    999    748
# 12  서대문구  2940       730    253    155    108    137    223    356    237
# 7    성북구  3958        83     78    170    230    323    594    460    867
#
#     2019년  2020년  2021년      최근증가율
# 0       9    200     43  16.578947
# 14    274    325      0  23.527101
# 5     209    223     63  26.670259
# 20    640    331     34  26.929260
# 21    358    420      3  27.422753
# 16    434    415      0  28.205980
# 3     262    461     76  29.835698
# 22    789    942      1  36.906030
# 12    343    397      1  38.078109
# 7     714    251    188  42.280895

# %%
pop_Seoul.head()
# Out:
#    자치구       인구수      한국인     외국인      고령자
# 0   합계  10013781  9733655  280126  1518239
# 1  종로구    161984   151217   10767    28073
# 2   중구    136469   126175   10294    23794
# 3  용산구    246165   229579   16586    39439
# 4  성동구    307193   299042    8151    44728

# %%
pop_Seoul.dtypes
# Out:
# 자치구    object
# 인구수     int64
# 한국인     int64
# 외국인     int64
# 고령자     int64
# dtype: object

# %%
pop_Seoul.drop([0], inplace = True)
pop_Seoul.head()
# Out:
#    자치구     인구수     한국인    외국인    고령자
# 1  종로구  161984  151217  10767  28073
# 2   중구  136469  126175  10294  23794
# 3  용산구  246165  229579  16586  39439
# 4  성동구  307193  299042   8151  44728
# 5  광진구  365990  350417  15573  48989

# %%
pop_Seoul.describe()
# Out:
#                  인구수            한국인           외국인           고령자
# count      25.000000      25.000000     25.000000     25.000000
# mean   400551.240000  389346.200000  11205.040000  60729.560000
# std    127661.623217  129398.149924   8162.361267  17027.908046
# min    136469.000000  126175.000000   2257.000000  23794.000000
# 25%    325875.000000  312985.000000   4490.000000  53038.000000
# 50%    404766.000000  395014.000000  10294.000000  61660.000000
# 75%    460532.000000  456339.000000  15573.000000  72172.000000
# max    680883.000000  674095.000000  32863.000000  89539.000000

# %%
n = pop_Seoul['자치구'].nunique()
print(f'자치구 개수: {n} 개 (NaN은 값을 카운트할 때 제외됨)')
pop_Seoul['자치구'].unique() #NaN 값 확인
# Out:
# 자치구 개수: 25 개 (NaN은 값을 카운트할 때 제외됨)
# array(['종로구', '중구', '용산구', '성동구', '광진구', '동대문구', '중랑구', '성북구', '강북구',
#        '도봉구', '노원구', '은평구', '서대문구', '마포구', '양천구', '강서구', '구로구', '금천구',
#        '영등포구', '동작구', '관악구', '서초구', '강남구', '송파구', '강동구'], dtype=object)

# %%
pop_Seoul.sample(3)
# Out:
#     자치구     인구수     한국인    외국인    고령자
# 1   종로구  161984  151217  10767  28073
# 14  마포구  386086  374570  11516  53283
# 3   용산구  246165  229579  16586  39439

# %%
pop_Seoul['외국인비율'] = pop_Seoul['외국인'] / pop_Seoul['인구수'] * 100
pop_Seoul['고령자비율'] = pop_Seoul['고령자'] / pop_Seoul['인구수'] * 100
pop_Seoul.sample(3)
# Out:
#     자치구     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 8   성북구  454532  442494  12038  72172  2.648438  15.878310
# 1   종로구  161984  151217  10767  28073  6.646953  17.330724
# 6  동대문구  362793  346156  16637  60367  4.585811  16.639516

# %%
pop_Seoul.sort_values(by = '인구수', ascending = False).head(5)
# Out:
#     자치구     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 24  송파구  680883  674095   6788  89539  0.996941  13.150424
# 16  강서구  595703  589302   6401  85992  1.074529  14.435381
# 23  강남구  549898  544804   5094  72602  0.926354  13.202812
# 11  노원구  535495  531037   4458  82682  0.832501  15.440294
# 21  관악구  516662  499374  17288  76664  3.346095  14.838328

# %%
pop_Seoul.sort_values(by = '외국인', ascending = False).head(5)
# Out:
#      자치구     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 19  영등포구  404766  371903  32863  59373  8.119012  14.668475
# 17   구로구  438308  405837  32471  67432  7.408261  15.384615
# 18   금천구  251370  232583  18787  38508  7.473843  15.319251
# 21   관악구  516662  499374  17288  76664  3.346095  14.838328
# 6   동대문구  362793  346156  16637  60367  4.585811  16.639516

# %%
pop_Seoul.sort_values(by = '외국인비율', ascending = False).head(5)
# Out:
#      자치구     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 19  영등포구  404766  371903  32863  59373  8.119012  14.668475
# 2     중구  136469  126175  10294  23794  7.543105  17.435462
# 18   금천구  251370  232583  18787  38508  7.473843  15.319251
# 17   구로구  438308  405837  32471  67432  7.408261  15.384615
# 3    용산구  246165  229579  16586  39439  6.737757  16.021368

# %%
pop_Seoul.sort_values(by = '고령자', ascending = False).head(5)
# Out:
#     자치구     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 24  송파구  680883  674095   6788  89539  0.996941  13.150424
# 16  강서구  595703  589302   6401  85992  1.074529  14.435381
# 11  노원구  535495  531037   4458  82682  0.832501  15.440294
# 12  은평구  482509  478019   4490  82245  0.930553  17.045278
# 21  관악구  516662  499374  17288  76664  3.346095  14.838328

# %%
#cctv 데이터와 인구 현황 데이터 합치기
CCTV_Seoul.head()
# Out:
#    자치구    총계  2012년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년  \
# 0  종로구  1772       813      0      0    210    150      1    261     85
# 1  중 구  2333        16    114     87     77    236    240    372    386
# 2  용산구  2383        34     71    234    125    221    298    351    125
# 3  성동구  3602       448    125    212    105    339    310    874    390
# 4  광진구  2588        35     57    100    187     98     52    675    465
#
#    2019년  2020년  2021년      최근증가율
# 0      9    200     43  16.578947
# 1    155    361    289  56.930693
# 2    307    617      0  66.570605
# 3    262    461     76  29.835698
# 4    712    175     32  57.009926

# %%
pop_Seoul.head()
# Out:
#    자치구     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 1  종로구  161984  151217  10767  28073  6.646953  17.330724
# 2   중구  136469  126175  10294  23794  7.543105  17.435462
# 3  용산구  246165  229579  16586  39439  6.737757  16.021368
# 4  성동구  307193  299042   8151  44728  2.653381  14.560228
# 5  광진구  365990  350417  15573  48989  4.255034  13.385338

# %%
# 자치구 열을 key 열로 활용해 merge
data_result = pd.merge(CCTV_Seoul, pop_Seoul, on = '자치구', how = 'outer')
data_result.head()
# Out:
#    자치구      총계  2012년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년  \
# 0  종로구  1772.0     813.0    0.0    0.0  210.0  150.0    1.0  261.0   85.0
# 1  중 구  2333.0      16.0  114.0   87.0   77.0  236.0  240.0  372.0  386.0
# 2  용산구  2383.0      34.0   71.0  234.0  125.0  221.0  298.0  351.0  125.0
# 3  성동구  3602.0     448.0  125.0  212.0  105.0  339.0  310.0  874.0  390.0
# 4  광진구  2588.0      35.0   57.0  100.0  187.0   98.0   52.0  675.0  465.0
#
#    2019년  2020년  2021년      최근증가율       인구수       한국인      외국인      고령자  \
# 0    9.0  200.0   43.0  16.578947  161984.0  151217.0  10767.0  28073.0
# 1  155.0  361.0  289.0  56.930693       NaN       NaN      NaN      NaN
# 2  307.0  617.0    0.0  66.570605  246165.0  229579.0  16586.0  39439.0
# 3  262.0  461.0   76.0  29.835698  307193.0  299042.0   8151.0  44728.0
# 4  712.0  175.0   32.0  57.009926  365990.0  350417.0  15573.0  48989.0
#
#       외국인비율      고령자비율
# 0  6.646953  17.330724
# 1       NaN        NaN
# 2  6.737757  16.021368
# 3  2.653381  14.560228
# 4  4.255034  13.385338

# %%
#null 값 확인
data_result.isnull().values.any()
# Out:
# True

# %%
data_result.dropna(axis = 0, inplace = True)
data_result.head()
# Out:
#     자치구      총계  2012년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년  \
# 0   종로구  1772.0     813.0    0.0    0.0  210.0  150.0    1.0  261.0   85.0
# 2   용산구  2383.0      34.0   71.0  234.0  125.0  221.0  298.0  351.0  125.0
# 3   성동구  3602.0     448.0  125.0  212.0  105.0  339.0  310.0  874.0  390.0
# 4   광진구  2588.0      35.0   57.0  100.0  187.0   98.0   52.0  675.0  465.0
# 5  동대문구  2497.0    1090.0  146.0   60.0   29.0  111.0  233.0  136.0  197.0
#
#    2019년  2020년  2021년      최근증가율       인구수       한국인      외국인      고령자  \
# 0    9.0  200.0   43.0  16.578947  161984.0  151217.0  10767.0  28073.0
# 2  307.0  617.0    0.0  66.570605  246165.0  229579.0  16586.0  39439.0
# 3  262.0  461.0   76.0  29.835698  307193.0  299042.0   8151.0  44728.0
# 4  712.0  175.0   32.0  57.009926  365990.0  350417.0  15573.0  48989.0
# 5  209.0  223.0   63.0  26.670259  362793.0  346156.0  16637.0  60367.0
#
#       외국인비율      고령자비율
# 0  6.646953  17.330724
# 2  6.737757  16.021368
# 3  2.653381  14.560228
# 4  4.255034  13.385338
# 5  4.585811  16.639516

# %%
data_result['자치구'].unique()
# Out:
# array(['종로구', '용산구', '성동구', '광진구', '동대문구', '중랑구', '성북구', '강북구', '도봉구',
#        '노원구', '은평구', '서대문구', '마포구', '양천구', '강서구', '구로구', '금천구', '영등포구',
#        '동작구', '관악구', '서초구', '강남구', '송파구', '강동구'], dtype=object)

# %%
# 총계 및 최근증가율 열만 남기고 cctv 데이터 열 삭제
del data_result['2012년 이전']
del data_result['2012년']
del data_result['2013년']
del data_result['2014년']
del data_result['2015년']
del data_result['2016년']
del data_result['2017년']
del data_result['2018년']
del data_result['2019년']
del data_result['2020년']
del data_result['2021년']
data_result.head()
# Out:
#     자치구      총계      최근증가율       인구수       한국인      외국인      고령자     외국인비율  \
# 0   종로구  1772.0  16.578947  161984.0  151217.0  10767.0  28073.0  6.646953
# 2   용산구  2383.0  66.570605  246165.0  229579.0  16586.0  39439.0  6.737757
# 3   성동구  3602.0  29.835698  307193.0  299042.0   8151.0  44728.0  2.653381
# 4   광진구  2588.0  57.009926  365990.0  350417.0  15573.0  48989.0  4.255034
# 5  동대문구  2497.0  26.670259  362793.0  346156.0  16637.0  60367.0  4.585811
#
#        고령자비율
# 0  17.330724
# 2  16.021368
# 3  14.560228
# 4  13.385338
# 5  16.639516

# %%
# 자치구 index 설정
data_result.set_index('자치구', inplace = True)
data_result.head()
# Out:
#           총계      최근증가율       인구수       한국인      외국인      고령자     외국인비율  \
# 자치구
# 종로구   1772.0  16.578947  161984.0  151217.0  10767.0  28073.0  6.646953
# 용산구   2383.0  66.570605  246165.0  229579.0  16586.0  39439.0  6.737757
# 성동구   3602.0  29.835698  307193.0  299042.0   8151.0  44728.0  2.653381
# 광진구   2588.0  57.009926  365990.0  350417.0  15573.0  48989.0  4.255034
# 동대문구  2497.0  26.670259  362793.0  346156.0  16637.0  60367.0  4.585811
#
#           고령자비율
# 자치구
# 종로구   17.330724
# 용산구   16.021368
# 성동구   14.560228
# 광진구   13.385338
# 동대문구  16.639516

# %%
data_result.rename(
    columns = {data_result.columns[0]: 'CCTV 소계', 
               data_result.columns[1]: 'CCTV 증가율'},
    inplace = True)
data_result.head()
# Out:
#       CCTV 소계   CCTV 증가율       인구수       한국인      외국인      고령자     외국인비율  \
# 자치구
# 종로구    1772.0  16.578947  161984.0  151217.0  10767.0  28073.0  6.646953
# 용산구    2383.0  66.570605  246165.0  229579.0  16586.0  39439.0  6.737757
# 성동구    3602.0  29.835698  307193.0  299042.0   8151.0  44728.0  2.653381
# 광진구    2588.0  57.009926  365990.0  350417.0  15573.0  48989.0  4.255034
# 동대문구   2497.0  26.670259  362793.0  346156.0  16637.0  60367.0  4.585811
#
#           고령자비율
# 자치구
# 종로구   17.330724
# 용산구   16.021368
# 성동구   14.560228
# 광진구   13.385338
# 동대문구  16.639516

# %%
import numpy as np
# 고령자 비율 대 CCTV 소계는 약한 음의 상관관계
np.corrcoef(data_result['고령자비율'], data_result['CCTV 소계'])
# Out:
# array([[ 1.        , -0.39573359],
#        [-0.39573359,  1.        ]])

# %%
# 외국인 비율 대 CCTV 소계는 거의 무관
np.corrcoef(data_result['외국인비율'], data_result['CCTV 소계'])
# Out:
# array([[ 1.       , -0.1055597],
#        [-0.1055597,  1.       ]])

# %%
# 인구 수 대 CCTV 소계는 약한 양의 상관관계
np.corrcoef(data_result['인구수'], data_result['CCTV 소계'])
# Out:
# array([[1.        , 0.44507086],
#        [0.44507086, 1.        ]])

# %%
# 소계 역순 정렬
data_result.sort_values(by = 'CCTV 소계', ascending = False).head(5)
# Out:
#      CCTV 소계   CCTV 증가율       인구수       한국인      외국인      고령자     외국인비율  \
# 자치구
# 강남구   6502.0  36.906030  549898.0  544804.0   5094.0  72602.0  0.926354
# 관악구   4942.0  26.929260  516662.0  499374.0  17288.0  76664.0  3.346095
# 구로구   4075.0  28.205980  438308.0  405837.0  32471.0  67432.0  7.408261
# 성북구   3958.0  42.280895  454532.0  442494.0  12038.0  72172.0  2.648438
# 은평구   3791.0  63.840830  482509.0  478019.0   4490.0  82245.0  0.930553
#
#          고령자비율
# 자치구
# 강남구  13.202812
# 관악구  14.838328
# 구로구  15.384615
# 성북구  15.878310
# 은평구  17.045278

# %%
# 인구 수 역순 정렬
data_result.sort_values(by = '인구수', ascending = False).head(5)
# Out:
#      CCTV 소계    CCTV 증가율       인구수       한국인      외국인      고령자     외국인비율  \
# 자치구
# 송파구   2854.0  101.079914  680883.0  674095.0   6788.0  89539.0  0.996941
# 강서구   2560.0   62.608696  595703.0  589302.0   6401.0  85992.0  1.074529
# 강남구   6502.0   36.906030  549898.0  544804.0   5094.0  72602.0  0.926354
# 노원구   2415.0   53.713528  535495.0  531037.0   4458.0  82682.0  0.832501
# 관악구   4942.0   26.929260  516662.0  499374.0  17288.0  76664.0  3.346095
#
#          고령자비율
# 자치구
# 송파구  13.150424
# 강서구  14.435381
# 강남구  13.202812
# 노원구  15.440294
# 관악구  14.838328

# %%
data_result.head()
# Out:
#       CCTV 소계   CCTV 증가율       인구수       한국인      외국인      고령자     외국인비율  \
# 자치구
# 종로구    1772.0  16.578947  161984.0  151217.0  10767.0  28073.0  6.646953
# 용산구    2383.0  66.570605  246165.0  229579.0  16586.0  39439.0  6.737757
# 성동구    3602.0  29.835698  307193.0  299042.0   8151.0  44728.0  2.653381
# 광진구    2588.0  57.009926  365990.0  350417.0  15573.0  48989.0  4.255034
# 동대문구   2497.0  26.670259  362793.0  346156.0  16637.0  60367.0  4.585811
#
#           고령자비율
# 자치구
# 종로구   17.330724
# 용산구   16.021368
# 성동구   14.560228
# 광진구   13.385338
# 동대문구  16.639516

# %% [markdown]
# 11주차 2005973 정윤아

# %%
#cctv와 인구현황 그래프 분석

# %%
import matplotlib.pyplot as plt
import platform

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin' :
    rc('font', family = 'AppleGothic')
elif platform.system() == 'Windows' :
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname = path).get_name()
    rc('font', family = font_name)
else :
    print('Unknown system,,, sorry~~~~!')

# %%
#cctv 소계 수평 막대 그래프
plt.figure()
# plot 함수로 차트 작성 (barh - 수평 막대 / bar - 수직 막대)
data_result['CCTV 소계'].plot(kind = 'barh', grid = True, figsize = (10, 10))

plt.show()

# %%
# 소계 정렬해서 시각화
data_result['CCTV 소계'] \
    .sort_values(ascending = True) \
    .plot(kind = 'barh', grid = True, figsize = (10, 10))
plt.xlabel('CCTV 설치 규모 (단위 : 대)')
plt.show()

# %%
# 인구 대비 cctv 비율 계산
data_result['CCTV 비율'] = data_result['CCTV 소계'] / data_result ['인구수'] * 100

data_result ['CCTV 비율'] \
    .sort_values(ascending = True) \
    .plot(kind = 'barh', grid = True, figsize = (10, 10))
plt.xlabel('인구 대비 CCTV 설치 비율 (단위 : %)')
plt.show()

# %%
#원본 정렬
data_result.sort_values(by= 'CCTV 비율', ascending = True, inplace = True)

# %%
#df.plot로 시각화
fig = plt.figure(figsize = (15, 10))
fig.suptitle('CCTV 규모 및 비율 분석', fontsize = 20)

# 왼쪽 그림 - CCTV 비율 시각화
ax1 = fig.add_subplot(121)
ax1.set_title('인구 대비 CCTV 비율', fontsize = 17)
data_result['CCTV 비율'] \
    .plot(kind = 'barh', grid = True, color = 'lightseagreen')
plt.xlabel('CCTV 설치 비율 (단위 : %)')
plt.ylabel('서울시 자치구')

# 오른쪽 그림 - CCTV 규모 시각화
ax2 = fig.add_subplot(122)
ax2.set_title('CCTV 규모', fontsize = 17)
data_result['CCTV 소계'] \
    .plot(kind = 'barh', grid = True, color = 'lightseagreen')
plt.xlabel('CCTV 설치 규모 (단위 : 대)')
plt.ylabel('서울시 자치구')

plt.show()

# %%
#plt.barh()로 시각화
fig = plt.figure(figsize = (15, 10))
fig.suptitle('CCTV 규모 및 비율 분석', fontsize = 20)

# 왼쪽 그림 - CCTV 비율 시각화
ax1 = fig.add_subplot(121)
ax1.set_title('인구 대비 CCTV 비율', fontsize = 17)
ax1.grid(zorder = 0)
plt.barh( y = data_result.index, width = data_result['CCTV 비율'],
        height = 0.5, zorder = 3, color = 'lightseagreen')
plt.xlabel('CCTV 설치 비율 (단위 : %)')
plt.ylabel('서울시 자치구')

# 오른쪽 그림 - CCTV 규모 시각화
ax2 = fig.add_subplot(122)
ax2.set_title('CCTV 규모', fontsize = 17)
ax2.grid(zorder = 0)
plt.barh( y = data_result.index, width = data_result['CCTV 소계'],
        height = 0.5, zorder = 3, color = 'lightseagreen')
plt.xlabel('CCTV 설치 규모 (단위 : 대)')
plt.ylabel('서울시 자치구')

plt.show()

# %%
# 인구 대비 cctv 설치 수량으로 산점도 시각화

plt.figure(figsize = (6, 6))
# 차례로 x, y, 점 크기
plt.scatter(data_result['인구수'],
           data_result['CCTV 소계'],
           s= 50)
plt.title('인구 및 CCTV 규모 산점도 \n')
plt.xlabel('인구 규모 (단위 : 명)')
plt.ylabel('CCTV 설치 규모 (단위 : 대)')
plt.grid()
plt.show()

# %%
# 추정 결과의 해석
# 차수를 1로 지정했으므로 1차 다항식으로 추정함.
# 차례로 X, Y, 다항식 값 지정
pf = np.polyfit(data_result['인구수'],
               data_result['CCTV 소계'],
               1)
pf
# Out:
# array([4.06336288e-03, 1.44016238e+03])

# %%
# y축 값에 대한 추정식
fy = np.poly1d(pf)
fy
# Out:
# poly1d([4.06336288e-03, 1.44016238e+03])

# %%
# x축 값 범위 지정 - 시작값 끝값 개수
fx = np.linspace(100000, 700000, 100)
# 따라서 시작값 부터 끝값까지의 범위에서 100개 생성해 배열함
fx
# Out:
# array([100000.        , 106060.60606061, 112121.21212121, 118181.81818182,
#        124242.42424242, 130303.03030303, 136363.63636364, 142424.24242424,
#        148484.84848485, 154545.45454545, 160606.06060606, 166666.66666667,
#        172727.27272727, 178787.87878788, 184848.48484848, 190909.09090909,
#        196969.6969697 , 203030.3030303 , 209090.90909091, 215151.51515152,
#        221212.12121212, 227272.72727273, 233333.33333333, 239393.93939394,
#        245454.54545455, 251515.15151515, 257575.75757576, 263636.36363636,
#        269696.96969697, 275757.57575758, 281818.18181818, 287878.78787879,
#        293939.39393939, 300000.        , 306060.60606061, 312121.21212121,
#        318181.81818182, 324242.42424242, 330303.03030303, 336363.63636364,
#        342424.24242424, 348484.84848485, 354545.45454545, 360606.06060606,
#        366666.66666667, 372727.27272727, 378787.87878788, 384848.48484848,
#        390909.09090909, 396969.6969697 , 403030.3030303 , 409090.90909091,
#        415151.51515152, 421212.12121212, 427272.72727273, 433333.33333333,
#        439393.93939394, 445454.54545455, 451515.15151515, 457575.75757576,
#        463636.36363636, 469696.96969697, 475757.57575758, 481818.18181818,
#        487878.78787879, 493939.39393939, 500000.        , 506060.60606061,
#        512121.21212121, 518181.81818182, 524242.42424242, 530303.03030303,
#        536363.63636364, 542424.24242424, 548484.84848485, 554545.45454545,
#        560606.06060606, 566666.66666667, 572727.27272727, 578787.87878788,
#        584848.48484848, 590909.09090909, 596969.6969697 , 603030.3030303 ,
#        609090.90909091, 615151.51515152, 621212.12121212, 627272.72727273,
#        633333.33333333, 639393.93939394, 645454.54545455, 651515.15151515,
#        657575.75757576, 663636.36363636, 669696.96969697, 675757.57575758,
#        681818.18181818, 687878.78787879, 693939.39393939, 700000.        ])

# %%
# 추정선 plot
plt.figure(figsize = (6, 6))
plt.scatter(data_result['인구수'],
           data_result['CCTV 소계'],
           s= 50)
plt.title('인구 및 CCTV 규모 산점도 \n (일차원 회귀방정식 포함)\n')
plt.xlabel('인구 규모 (단위 : 명)')
plt.ylabel('CCTV 설치 규모 (단위 : 대)')
plt.grid()
plt.show()

# %%
plt.figure(figsize = (6, 6))
# 산점도
plt.scatter(data_result['인구수'],
           data_result['CCTV 소계'],
           s= 50)
# 추정선
plt.plot(fx, fy(fx), ls = 'dashed', lw = 3, color = 'g')

# 마커 옆에 자치구 이름 출력
# data_result 행 개수 만큼 반복
for n in range(len(data_result)):
    #각 x좌표 텍스트 위치, y좌표 텍스트 위치, 텍스트 내용, 폰트 크기
    plt.text(data_result['인구수'][n] + 10000,
            data_result['CCTV 소계'][n] - 20,
            data_result.index[n],
            fontsize = 10)

plt.title('인구 및 CCTV 규모 산점도 \n (일차원 회귀방정식 포함)\n (markertext 포함) \n')
plt.xlabel('인구 규모 (단위 : 명)')
plt.ylabel('CCTV 설치 규모 (단위 : 대)')
plt.grid()
plt.show()

# %%
# 회귀 추정 오차 가시화

#pf = np.polyfit(data_result['인구수'],
#               data_result['CCTV 소계'],
#               1)
#fy = np.poly1d(pf)
#fx = np.linspace(100000, 700000, 100)

# 추정 오차 = 절대값(실측치 - 추정치) 계산 및 열 삽입
data_result['오차'] = np.abs(
    data_result['CCTV 소계'] - fy(data_result['인구수'])
)

#추정오차 역순으로 정렬
df_sort = data_result.sort_values(by= '오차', ascending = False)
df_sort.head()
# Out:
#      CCTV 소계    CCTV 증가율       인구수       한국인      외국인      고령자     외국인비율  \
# 자치구
# 강남구   6502.0   36.906030  549898.0  544804.0   5094.0  72602.0  0.926354
# 관악구   4942.0   26.929260  516662.0  499374.0  17288.0  76664.0  3.346095
# 송파구   2854.0  101.079914  680883.0  674095.0   6788.0  89539.0  0.996941
# 강서구   2560.0   62.608696  595703.0  589302.0   6401.0  85992.0  1.074529
# 노원구   2415.0   53.713528  535495.0  531037.0   4458.0  82682.0  0.832501
#
#          고령자비율   CCTV 비율           오차
# 자치구
# 강남구  13.202812  1.182401  2827.402501
# 관악구  14.838328  0.956525  1402.452429
# 송파구  13.150424  0.419162  1352.837087
# 강서구  14.435381  0.429744  1300.719836
# 노원구  15.440294  0.450985  1201.072884

# %%
# CCTV와 인구 현황 그래프로 분석하기 - 최종

plt.figure(figsize=(14, 10))

# 산점도 그리기
# 각 x, y, 마커 색상, 마커 크기
plt.scatter(df_sort['인구수'],
           df_sort['CCTV 소계'],
            c = df_sort['오차'],
           s= 50)
# 추세선 그리기
plt.plot(fx, fy(fx), ls = 'dashed', lw = 3, color = 'g')

# 마커 옆에 자치구 이름 출력
# data_result 행 개수 만큼 반복
for n in range(len(data_result)):
    #각 x좌표 텍스트 위치, y좌표 텍스트 위치, 텍스트 내용, 폰트 크기
    plt.text(df_sort['인구수'][n] + 5000,
            df_sort['CCTV 소계'][n] - 20,
            df_sort.index[n],
            fontsize = 15)

# 색상 조견 막대 (수직 방향이 직선값임)
plt.colorbar()

plt.title('인구 및 CCTV 규모 산점도\n (일차원 회귀방정식 포함)\n (markertext 포함)\n (추정오차 포함)\n')
plt.xlabel('인구 규모 (단위 : 명)')
plt.ylabel('CCTV 설치 규모 (단위 : 대)')
plt.grid()
plt.show()
